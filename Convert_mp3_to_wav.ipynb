# %%
import os
from pydub import AudioSegment
import librosa
import librosa.display
import IPython.display
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# %%
# mp3를 wav로 변환
top_dir = 'president_audio_record_data'
presidents_count = 1
for total_count in range(len(speech_data)):
    sound = AudioSegment.from_mp3(president_name[total_count] + president_count + ".mp3")
    sound.export(president_name[total_count] + president_count + ".wav", format='wav')
    if total_count < len(president_name) - 1 :
        if president_name[total_count] != president_name[total_count + 1] :
            presidents_count = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-e480d18289bd> in <module>()
#       2 presidents_count = 1
#       3
# ----> 4 for total_count in range(len(speech_data)):
#       5     sound = AudioSegment.from_mp3(president_name[total_count] + president_count + ".mp3")
#       6     sound.export(president_name[total_count] + president_count + ".wav", format='wav')
#
# NameError: name 'speech_data' is not defined

# %%
# %matplotlib inline

for total_count in range(len(speech_data))
audio_path = '박정희13.wav'
y, sr = librosa.load(audio_path)
IPython.display.Audio(data=y, rate = sr)

#D = librosa.amplitude_to_db(librosa.stft(y[:1024]), ref=np.max)
#plt.plot(D.flatten())
#plt.show()

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128) 
 
log_S = librosa.amplitude_to_db(S, ref=np.max)
plt.figure(figsize=(12, 4))
librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')
plt.title('mel power spectrogram')
plt.colorbar(format='%+02.0f dB')
plt.tight_layout()
plt.show()

# %%
min_level_db = -100
 
def _normalize(S):
    return np.clip((S - min_level_db) / -min_level_db, 0, 1)


norm_S = _normalize(log_S)
 
plt.figure(figsize=(12, 4))
librosa.display.specshow(norm_S, sr=sr, x_axis='time', y_axis='mel')
plt.title('norm mel power spectrogram')
plt.colorbar(format='%+0.1f dB')
plt.tight_layout()
plt.show()

# %%
import hgtk
 
ori_sent="len da"
jamo_sent = hgtk.text.decompose(ori_sent)
jamo_sent = jamo_sent.replace('ᴥ', '')
print(jamo_sent)
# Out:
# len da
# 6

# %%
char_frame_num = int(time_frame_num / len(jamo_sent)) #가로 사이즈
print(char_frame_num)
print(time_frame_num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-b178843631df> in <module>()
# ----> 1 char_frame_num = int(time_frame_num / len(jamo_sent)) #가로 사이즈
#       2 print(char_frame_num)
#       3 print(time_frame_num)
#
# NameError: name 'time_frame_num' is not defined
